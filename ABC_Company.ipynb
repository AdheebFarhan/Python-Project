# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_excel(r"C:\Users\user\Downloads\myexcel.xlsx")
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %% [markdown]
# Data preprocessing

# %%
# Remove number and college columns
df.drop(['Number','College'], axis=1, inplace=True)
df
# Out:
#               Name            Team Position  Age               Height  Weight  \
# 0    Avery Bradley  Boston Celtics       PG   25  2023-02-06 00:00:00     180
# 1      Jae Crowder  Boston Celtics       SF   25  2023-06-06 00:00:00     235
# 2     John Holland  Boston Celtics       SG   27  2023-05-06 00:00:00     205
# 3      R.J. Hunter  Boston Celtics       SG   22  2023-05-06 00:00:00     185
# 4    Jonas Jerebko  Boston Celtics       PF   29  2023-10-06 00:00:00     231
# ..             ...             ...      ...  ...                  ...     ...
# 453   Shelvin Mack       Utah Jazz       PG   26  2023-03-06 00:00:00     203
# 454      Raul Neto       Utah Jazz       PG   24  2023-01-06 00:00:00     179
# 455   Tibor Pleiss       Utah Jazz        C   26  2023-03-07 00:00:00     256
# 456    Jeff Withey       Utah Jazz        C   26                  7-0     231
# 457       Priyanka       Utah Jazz        C   25  2023-03-07 00:00:00     231
#
#         Salary
# 0    7730337.0
# ...

# %%
# add random numbers between 150 and 180 in column height
random_numbers = np.random.randint(150,180,size = len(df))
df['Height'] = random_numbers
df
# Out:
#               Name            Team Position  Age  Height  Weight     Salary
# 0    Avery Bradley  Boston Celtics       PG   25     154     180  7730337.0
# 1      Jae Crowder  Boston Celtics       SF   25     155     235  6796117.0
# 2     John Holland  Boston Celtics       SG   27     171     205        NaN
# 3      R.J. Hunter  Boston Celtics       SG   22     177     185  1148640.0
# 4    Jonas Jerebko  Boston Celtics       PF   29     174     231  5000000.0
# ..             ...             ...      ...  ...     ...     ...        ...
# 453   Shelvin Mack       Utah Jazz       PG   26     177     203  2433333.0
# 454      Raul Neto       Utah Jazz       PG   24     177     179   900000.0
# 455   Tibor Pleiss       Utah Jazz        C   26     175     256  2900000.0
# 456    Jeff Withey       Utah Jazz        C   26     177     231   947276.0
# 457       Priyanka       Utah Jazz        C   25     155     231   947276.0
#
# [458 rows x 7 columns]

# %%
# replace null value in salary using median methode
median = df['Salary'].median()
df['Salary'].fillna(median, inplace=True)
df.to_excel('ABC_dataset.xlsx', index=False)
df
# Out:
#               Name            Team Position  Age  Height  Weight     Salary
# 0    Avery Bradley  Boston Celtics       PG   25     154     180  7730337.0
# 1      Jae Crowder  Boston Celtics       SF   25     155     235  6796117.0
# 2     John Holland  Boston Celtics       SG   27     171     205  2836186.0
# 3      R.J. Hunter  Boston Celtics       SG   22     177     185  1148640.0
# 4    Jonas Jerebko  Boston Celtics       PF   29     174     231  5000000.0
# ..             ...             ...      ...  ...     ...     ...        ...
# 453   Shelvin Mack       Utah Jazz       PG   26     177     203  2433333.0
# 454      Raul Neto       Utah Jazz       PG   24     177     179   900000.0
# 455   Tibor Pleiss       Utah Jazz        C   26     175     256  2900000.0
# 456    Jeff Withey       Utah Jazz        C   26     177     231   947276.0
# 457       Priyanka       Utah Jazz        C   25     155     231   947276.0
#
# [458 rows x 7 columns]

# %% [markdown]
# REPORT

# %%
# Count the number of employees in each team
team_counts = df['Team'].value_counts()

# Calculate percentage split
total_employees = len(df)
percentage_split = (team_counts / total_employees) * 100
team_df = pd.DataFrame({'Team':team_counts.index,'Number of employees':team_counts.values,'Percentage':percentage_split.values})
team_df.set_index('Team',inplace=True)
team_df
# Out:
#                         Number of employees  Percentage
# Team
# New Orleans Pelicans                     19    4.148472
# Memphis Grizzlies                        18    3.930131
# Utah Jazz                                16    3.493450
# New York Knicks                          16    3.493450
# Milwaukee Bucks                          16    3.493450
# Brooklyn Nets                            15    3.275109
# Portland Trail Blazers                   15    3.275109
# Oklahoma City Thunder                    15    3.275109
# Denver Nuggets                           15    3.275109
# Washington Wizards                       15    3.275109
# Miami Heat                               15    3.275109
# Charlotte Hornets                        15    3.275109
# Atlanta Hawks                            15    3.275109
# San Antonio Spurs                        15    3.275109
# Houston Rockets                          15    3.275109
# Boston Celtics                           15    3.275109
# ...

# %%
counts_team_unique = df['Team'].nunique()
counts_team_unique
# Out:
# 30

# %%
plt.figure(figsize=(10,10))
plt.pie(percentage_split.values,labels=team_counts.index, autopct='%1.1f%%')
plt.title('Percentage splitting with respect to the total employees')
plt.show()

# %%
plt.bar(team_counts.index,team_counts.values,edgecolor="black")
plt.xlabel("Team")
plt.ylabel("Number of employees")
plt.title("Number of employees in each team")
plt.xticks(rotation='vertical')
plt.figure(figsize=(10,10))
plt.show()

# %%
#Segregatethe employees with respect to position
positions = df['Position'].unique()
employees_by_position = {position:df[df['Position'] == position] for position in positions}
for position, employees_df in employees_by_position.items():
    print(f'Employees in position "{position}":')
    print(employees_df.to_string(index=False))
    print()
# Out:
# Employees in position "PG":
#                    Name                   Team Position  Age  Height  Weight     Salary
#           Avery Bradley         Boston Celtics       PG   25     154     180  7730337.0
#            Terry Rozier         Boston Celtics       PG   22     151     190  1824360.0
#            Marcus Smart         Boston Celtics       PG   22     158     220  3431040.0
#           Isaiah Thomas         Boston Celtics       PG   27     157     185  6912869.0
#            Jarrett Jack          Brooklyn Nets       PG   32     167     200  6300000.0
#            Shane Larkin          Brooklyn Nets       PG   23     154     175  1500000.0
#            Donald Sloan          Brooklyn Nets       PG   28     150     205   947276.0
#           Jose Calderon        New York Knicks       PG   34     169     200  7402812.0
#            Jerian Grant        New York Knicks       PG   23     153     195  1572360.0
# ...

# %%
# Age grouping
age_data = df['Age']
plt.figure(figsize=(6, 4)) 
# Create a histogram
plt.hist(age_data, bins=[15, 20, 25, 30, 35,40,45,50], edgecolor='black')

# Add labels and title
plt.xlabel("Age")
plt.ylabel("Number of Employees")
plt.title("Histogram of Age Data")

# Show the plot
plt.show()

# %%
# Salary grouping by team
team = df['Team']
salary = df['Salary']
plt.figure(figsize=(6, 4))  # Create a figure with a specific size

plt.bar(team, salary, color='blue')
plt.xticks(rotation='vertical')
plt.title('Bar Chart ')  # Add a title
plt.xlabel('Team')  # Add x-axis label
plt.ylabel('Salary')  # Add y-axis label

plt.grid(True)  # Add a grid

plt.show()  # Display the plot

# %%
# Salary grouping by position
position = df['Position']
salary = df['Salary']
plt.figure(figsize=(6, 4))  # Create a figure with a specific size

plt.bar(position, salary, color='blue')
plt.xticks(rotation='vertical')
plt.title('Bar Chart ')  # Add a title
plt.xlabel('Position')  # Add x-axis label
plt.ylabel('Salary')  # Add y-axis label

plt.grid(True)  # Add a grid

plt.show()  # Display the plot

# %%
# Find out under which team and position Spending in terms of salary is high
max_salary_spending =  df.groupby(['Team', 'Position'])['Salary'].sum().idxmax()
max_salary_spending
# Out:
# ('Los Angeles Lakers', 'SF')

# %%
# Correlation between Age and Salary
correlation = df['Age'].corr(df['Salary'])

print(f"The correlation between age and salary is: {correlation:.5f}")
# Out:
# The correlation between age and salary is: 0.20912

# %%
# Scatter plot of Age Vs Salary
plt.figure(figsize=(8, 6))
plt.scatter(df['Age'], df['Salary'], alpha=0.4)
plt.title('Scatter Plot of Age vs Salary')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid(True)
plt.show()

# %%
# Correlation between Age an Salary Visually
correlation_matrix = df[['Age', 'Salary']].corr()
print(correlation_matrix)

# Create a heatmap plot
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Correlation Heatmap of Age and Salary')
plt.show()
# Out:
#              Age    Salary
# Age     1.000000  0.209124
# Salary  0.209124  1.000000
